# %% [markdown]
# # Workflow - Sulamérica Challenge - ML
#
#
# ## TRATAMENTO DE DADOS

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
allergies = pd.read_csv('data/csv/allergies.csv')
patients = pd.read_csv('data/csv/patients.csv')
careplans = pd.read_csv('data/csv/careplans.csv')
conditions = pd.read_csv('data/csv/conditions.csv')
devices = pd.read_csv('data/csv/devices.csv')
encounters = pd.read_csv('data/csv/encounters.csv')
imaging_studies = pd.read_csv('data/csv/imaging_studies.csv')
immunizations = pd.read_csv('data/csv/immunizations.csv')
medications = pd.read_csv('data/csv/medications.csv')
observations = pd.read_csv('data/csv/observations.csv')
organizations = pd.read_csv('data/csv/organizations.csv')
payers = pd.read_csv('data/csv/payers.csv')
payer_transitions = pd.read_csv('data/csv/payer_transitions.csv')
procedures = pd.read_csv('data/csv/procedures.csv')
providers = pd.read_csv('data/csv/providers.csv')
supplies = pd.read_csv('data/csv/supplies.csv')

# %%
patients = patients.rename(columns={'Id': 'PATIENT'})
careplans = careplans.rename(columns={'Id': 'CAREPLAN_ID'})
encounters = encounters.rename(columns={'Id': 'ENCOUNTER'})
observations = observations.rename(columns={'CODE': 'OBSERVATIONS_CODE'})
observations = observations.rename(columns={'DESCRIPTION': 'OBSERVATIONS_DESCRIPTION'})
imaging_studies = imaging_studies.rename(columns={'Id': 'IMAGING_STUDIES_ID'})

# %%
pd.set_option('display.max_columns', None)

# %%
all_data = pd.merge(
    patients,
    encounters,
    how="left",
    on=['PATIENT'],
    copy=True,
    indicator=False,
    validate=None)

# %%
all_data[all_data['PATIENT'].isin(['37d96a0f-ead9-7a28-1c27-42a2da0c0c97'])].head(3)
# Out:
#                                   PATIENT   BIRTHDATE DEATHDATE          SSN  \
# 668  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
# 669  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
# 670  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
#
#        DRIVERS    PASSPORT PREFIX     FIRST          LAST SUFFIX MAIDEN  \
# 668  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
# 669  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
# 670  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
#
#     MARITAL   RACE    ETHNICITY GENDER                   BIRTHPLACE  \
# 668       M  white  nonhispanic      M  Holbrook  Massachusetts  US
# 669       M  white  nonhispanic      M  Holbrook  Massachusetts  US
# 670       M  white  nonhispanic      M  Holbrook  Massachusetts  US
#
#                        ADDRESS     CITY          STATE           COUNTY  ZIP  \
# 668  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
# 669  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
# 670  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
#
#            LAT        LON  HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  \
# 668  42.047835 -70.955601             28973.06               294.96
# 669  42.047835 -70.955601             28973.06               294.96
# 670  42.047835 -70.955601             28973.06               294.96
#
#                                 ENCOUNTER                 START  \
# 668  94853162-008b-f579-00be-f15d22fb6f7a  1991-07-12T16:50:15Z
# 669  21475337-cc5f-0450-0a7c-c01d6046cf8e  1993-10-08T16:50:15Z
# 670  3863a43e-6037-a683-3150-53c8775410be  1993-10-08T16:50:15Z
#
#                      STOP                          ORGANIZATION  \
# 668  1991-07-12T17:05:15Z  2c5d106d-836c-35fe-96c1-36797e2319ac
# 669  1993-10-08T17:05:15Z  c44f361c-2efb-3050-8f97-0354a12e2920
# 670  1993-10-08T17:05:15Z  226098a2-6a40-3588-b5bb-db56c3a30a04
#
#                                  PROVIDER  \
# 668  8cb795bb-fc03-3237-b02f-14c01f71ef32
# 669  d94bbaea-9355-379d-8978-e3cb17ae0d40
# 670  59ae271f-d96e-3768-8b93-a3953f55451a
#
#                                     PAYER ENCOUNTERCLASS       CODE  \
# 668  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76       wellness  162673000
# 669  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     outpatient  185349003
# 670  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     ambulatory  185347001
#
#                                     DESCRIPTION  BASE_ENCOUNTER_COST  \
# 668  General examination of patient (procedure)               129.16
# 669          Encounter for check up (procedure)                77.49
# 670                       Encounter for problem                77.49
#
#      TOTAL_CLAIM_COST  PAYER_COVERAGE   REASONCODE  REASONDESCRIPTION
# 668            129.16             0.0          NaN                NaN
# 669             77.49             0.0          NaN                NaN
# 670             77.49             0.0  271737000.0  Anemia (disorder)

# %%
procedures[procedures['PATIENT'].isin(['37d96a0f-ead9-7a28-1c27-42a2da0c0c97'])].head(3)
# Out:
#                      DATE                               PATIENT  \
# 756  2012-05-18T16:50:15Z  37d96a0f-ead9-7a28-1c27-42a2da0c0c97
# 757  2014-01-03T16:50:15Z  37d96a0f-ead9-7a28-1c27-42a2da0c0c97
# 758  2014-05-23T16:50:15Z  37d96a0f-ead9-7a28-1c27-42a2da0c0c97
#
#                                 ENCOUNTER       CODE  \
# 756  affa320f-bed0-abe1-799c-fe25a24f750a  430193006
# 757  c836be3a-1bfe-94cf-9700-ac6543ab53c8  430193006
# 758  27595d37-7cf7-4f5b-4c5b-b82209b61c16  430193006
#
#                                DESCRIPTION  BASE_COST  REASONCODE  \
# 756  Medication Reconciliation (procedure)     639.85         NaN
# 757  Medication Reconciliation (procedure)     700.43         NaN
# 758  Medication Reconciliation (procedure)     939.37         NaN
#
#     REASONDESCRIPTION
# 756               NaN
# 757               NaN
# 758               NaN

# %%
all_data = pd.merge(
    all_data,
    procedures,
    how="left",
    on=['PATIENT', 'ENCOUNTER'],
    copy=True,
    indicator=False,
    validate=None)

# %%
all_data[all_data['PATIENT'].isin(['37d96a0f-ead9-7a28-1c27-42a2da0c0c97'])].head(3)
# Out:
#                                    PATIENT   BIRTHDATE DEATHDATE          SSN  \
# 1140  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
# 1141  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
# 1142  37d96a0f-ead9-7a28-1c27-42a2da0c0c97  1972-05-12       NaN  999-60-5458
#
#         DRIVERS    PASSPORT PREFIX     FIRST          LAST SUFFIX MAIDEN  \
# 1140  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
# 1141  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
# 1142  S99954850  X44639653X    Mr.  Kirby843  Lueilwitz711    NaN    NaN
#
#      MARITAL   RACE    ETHNICITY GENDER                   BIRTHPLACE  \
# 1140       M  white  nonhispanic      M  Holbrook  Massachusetts  US
# 1141       M  white  nonhispanic      M  Holbrook  Massachusetts  US
# 1142       M  white  nonhispanic      M  Holbrook  Massachusetts  US
#
#                         ADDRESS     CITY          STATE           COUNTY  ZIP  \
# 1140  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
# 1141  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
# 1142  655 Reichert Estate Apt 2  Whitman  Massachusetts  Plymouth County  NaN
#
#             LAT        LON  HEALTHCARE_EXPENSES  HEALTHCARE_COVERAGE  \
# 1140  42.047835 -70.955601             28973.06               294.96
# 1141  42.047835 -70.955601             28973.06               294.96
# 1142  42.047835 -70.955601             28973.06               294.96
#
#                                  ENCOUNTER                 START  \
# 1140  94853162-008b-f579-00be-f15d22fb6f7a  1991-07-12T16:50:15Z
# 1141  21475337-cc5f-0450-0a7c-c01d6046cf8e  1993-10-08T16:50:15Z
# 1142  3863a43e-6037-a683-3150-53c8775410be  1993-10-08T16:50:15Z
#
#                       STOP                          ORGANIZATION  \
# 1140  1991-07-12T17:05:15Z  2c5d106d-836c-35fe-96c1-36797e2319ac
# 1141  1993-10-08T17:05:15Z  c44f361c-2efb-3050-8f97-0354a12e2920
# 1142  1993-10-08T17:05:15Z  226098a2-6a40-3588-b5bb-db56c3a30a04
#
#                                   PROVIDER  \
# 1140  8cb795bb-fc03-3237-b02f-14c01f71ef32
# 1141  d94bbaea-9355-379d-8978-e3cb17ae0d40
# 1142  59ae271f-d96e-3768-8b93-a3953f55451a
#
#                                      PAYER ENCOUNTERCLASS     CODE_x  \
# 1140  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76       wellness  162673000
# 1141  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     outpatient  185349003
# 1142  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     ambulatory  185347001
#
#                                    DESCRIPTION_x  BASE_ENCOUNTER_COST  \
# 1140  General examination of patient (procedure)               129.16
# 1141          Encounter for check up (procedure)                77.49
# 1142                       Encounter for problem                77.49
#
#       TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE_x REASONDESCRIPTION_x DATE  \
# 1140            129.16             0.0           NaN                 NaN  NaN
# 1141             77.49             0.0           NaN                 NaN  NaN
# 1142             77.49             0.0   271737000.0   Anemia (disorder)  NaN
#
#       CODE_y DESCRIPTION_y  BASE_COST  REASONCODE_y REASONDESCRIPTION_y
# 1140     NaN           NaN        NaN           NaN                 NaN
# 1141     NaN           NaN        NaN           NaN                 NaN
# 1142     NaN           NaN        NaN           NaN                 NaN

# %%
observations.head(3)
# Out:
#                    DATE                               PATIENT  \
# 0  2011-04-17T07:18:08Z  a3795ec8-54f3-e99e-a4b1-4c067f3141d7
# 1  2011-03-29T01:52:13Z  a074203a-4773-9330-fc6a-06307ed6b3d7
# 2  2011-04-17T07:18:08Z  a3795ec8-54f3-e99e-a4b1-4c067f3141d7
#
#                               ENCOUNTER OBSERVATIONS_CODE  \
# 0  cdfce94c-98f2-5331-6868-b86da30ee994            8302-2
# 1  76e82eab-c1ce-1677-9f8c-0bb5c07d3328            8302-2
# 2  cdfce94c-98f2-5331-6868-b86da30ee994           72514-3
#
#                             OBSERVATIONS_DESCRIPTION  VALUE    UNITS     TYPE
# 0                                        Body Height  122.2       cm  numeric
# 1                                        Body Height  166.9       cm  numeric
# 2  Pain severity - 0-10 verbal numeric rating [Sc...    2.0  {score}  numeric

# %%
all_data = pd.merge(
    all_data,
    allergies,
    how="left",
    on=['PATIENT', 'ENCOUNTER'],
    copy=True,
    indicator=False,
    validate=None)

# %%
all_data = pd.merge(
    all_data,
    medications,
    how="left",
    on=['PATIENT', 'ENCOUNTER'],
    copy=True,
    indicator=False,
    validate=None)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

# %%
columns_bug = []

# %%
for i in all_data.columns:
    try:
        all_data[i] = labelencoder.fit_transform(all_data[i].astype(str))
    except:
        if i not in columns_bug:
            all_data.drop(i, axis=1, inplace=True)
            columns_bug.append(i)
        else:
            continue

# %% [markdown]
# ## CRIANDO O MODEL

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
# Create X (features matrix or data or feature variables)
x = all_data.drop('REASONDESCRIPTION', axis=1)

# Create Y (labels)
y = all_data['REASONDESCRIPTION']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(x_train, y_train)
# Out:
# 1.0

# %%
clf.score(x_test, y_test)
# Out:
# 0.9995673180933151

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
y_preds = clf.predict(x_test)

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.99      1.00      1.00       542
#            2       1.00      1.00      1.00      1274
#            3       1.00      1.00      1.00      1252
#            4       1.00      0.88      0.93         8
#            5       1.00      0.89      0.94        53
#            6       1.00      1.00      1.00       860
#            7       0.99      0.99      0.99       202
#            8       1.00      0.93      0.97        15
#            9       1.00      1.00      1.00       130
#           10       1.00      1.00      1.00       386
#           11       1.00      0.93      0.97        15
#           12       0.99      1.00      1.00      4601
#           13       1.00      1.00      1.00       756
#           14       1.00      0.98      0.99       490
#           15       0.91      0.95      0.93        21
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00        39
#           18       1.00      1.00      1.00      6235
#           19       0.97      1.00      0.99        73
#           20       0.00      0.00      0.00         1
#           21       1.00      0.43      0.60         7
#           22       1.00      1.00      1.00        14
#           23       1.00      1.00      1.00      2178
#           24       1.00      1.00      1.00     23153
#           25       1.00      1.00      1.00      1713
#           26       1.00      1.00      1.00        21
#           27       1.00      1.00      1.00         9
#           28       1.00      0.94      0.97        49
#           29       1.00      1.00      1.00        26
#           30       1.00      1.00      1.00      1470
#           31       1.00      0.92      0.96        36
#           32       1.00      1.00      1.00        16
#           33       1.00      1.00      1.00        47
#           34       1.00      1.00      1.00        10
#           35       1.00      1.00      1.00         7
#           36       1.00      1.00      1.00        12
#           37       1.00      1.00      1.00       436
#           38       1.00      0.99      1.00       542
#           39       1.00      1.00      1.00         3
#           40       1.00      1.00      1.00         8
#           41       1.00      1.00      1.00         5
#           42       1.00      1.00      1.00       459
#           43       1.00      0.79      0.88        14
#           44       0.99      1.00      1.00       167
#           45       0.99      1.00      1.00       221
#           46       1.00      1.00      1.00     63348
#
#     accuracy                           1.00    110936
#    macro avg       0.98      0.95      0.96    110936
# weighted avg       1.00      1.00      1.00    110936
# /home/fredbrowne/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
accuracy_score(y_test, y_preds)
# Out:
# 0.9995673180933151

# %% [markdown]
# # SALVAR MODEL

# %%
# SALVAR MODEL
import pickle

pickle.dump(clf, open('random_forest_model_1.pk1', 'wb'))
